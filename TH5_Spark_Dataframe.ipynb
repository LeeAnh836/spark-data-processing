// %% [markdown]
// <div style="text-align: center; line-height: 0; padding-top: 9px;">
//   <img src="https://cct.ued.vnu.edu.vn/admin//lienketlinkphai/brtunv-7_87_anhlienket.png" alt="Databricks Learning" style="width: 600px">
// </div>

// %% [markdown]
// Các bạn sẽ sử dụng Databricks để lấy dữ liệu từ bảng chi tiết chuyến đi của của một hãng taxi tại thành phố New York `samples.nyctaxi.trips` có sẵn trên Databricks.
// Lưu ý: Bảng sẽ xuất hiện sau khi bật cluster.
//
// Thông tin các trường và ý nghĩa như sau:
//
// | Tên trường | Ý nghĩa |
// | --- | --- |
// | tpep_pickup_datetime | Thời gian đón khách (chính xác đến milisecond) |
// | tpep_dropoff_datetime | Thời gian trả khách (chính xác đến milisecond) |
// | trip_distance | Quãng đường chuyến đi (đơn vị: dặm - miles) |
// | fare_amount | Số tiền (đơn vị: $) |
// | pickup_zip | Mã điểm đón khách |
// | dropoff_zip | Mã điểm trả khách |

// %%
val input = spark.read.table("samples.nyctaxi.trips")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">input: org.apache.spark.sql.DataFrame = [tpep_pickup_datetime: timestamp, tpep_dropoff_datetime: timestamp ... 4 more fields]
// </div>

// %%
display(input.limit(10))
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>trip_distance</th><th>fare_amount</th><th>pickup_zip</th><th>dropoff_zip</th></tr></thead><tbody><tr><td>2016-02-14T16:52:13.000+0000</td><td>2016-02-14T17:16:04.000+0000</td><td>4.94</td><td>19.0</td><td>10282</td><td>10171</td></tr><tr><td>2016-02-04T18:44:19.000+0000</td><td>2016-02-04T18:46:00.000+0000</td><td>0.28</td><td>3.5</td><td>10110</td><td>10110</td></tr><tr><td>2016-02-17T17:13:57.000+0000</td><td>2016-02-17T17:17:55.000+0000</td><td>0.7</td><td>5.0</td><td>10103</td><td>10023</td></tr><tr><td>2016-02-18T10:36:07.000+0000</td><td>2016-02-18T10:41:45.000+0000</td><td>0.8</td><td>6.0</td><td>10022</td><td>10017</td></tr><tr><td>2016-02-22T14:14:41.000+0000</td><td>2016-02-22T14:31:52.000+0000</td><td>4.51</td><td>17.0</td><td>10110</td><td>10282</td></tr><tr><td>2016-02-05T06:45:02.000+0000</td><td>2016-02-05T06:50:26.000+0000</td><td>1.8</td><td>7.0</td><td>10009</td><td>10065</td></tr><tr><td>2016-02-15T15:03:28.000+0000</td><td>2016-02-15T15:18:45.000+0000</td><td>2.58</td><td>12.0</td><td>10153</td><td>10199</td></tr><tr><td>2016-02-25T19:09:26.000+0000</td><td>2016-02-25T19:24:50.000+0000</td><td>1.4</td><td>11.0</td><td>10112</td><td>10069</td></tr><tr><td>2016-02-13T16:28:18.000+0000</td><td>2016-02-13T16:36:36.000+0000</td><td>1.21</td><td>7.5</td><td>10023</td><td>10153</td></tr><tr><td>2016-02-14T00:03:48.000+0000</td><td>2016-02-14T00:10:24.000+0000</td><td>0.6</td><td>6.0</td><td>10012</td><td>10003</td></tr></tbody></table></div>

// %% [markdown]
// Bài 1: Hãy tính tiền trung bình của các chuyến đi có quãng đường đi lớn hơn 2 miles

// %%
import org.apache.spark.sql.functions._
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">import org.apache.spark.sql.functions._
// </div>

// %%
val lesson1 = input.filter($"trip_distance" > 2).agg(round(avg($"fare_amount"), 5).as("AVG_AMOUNT"))
display(lesson1)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AVG_AMOUNT</th></tr></thead><tbody><tr><td>19.7202</td></tr></tbody></table></div>

// %% [markdown]
// Bài 2: Hãy cho biết thời gian trung bình của mỗi chuyến đi trên tổng số chuyến đi đã thực hiện

// %%
input.printSchema()
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">root
// -- tpep_pickup_datetime: timestamp (nullable = true)
// -- tpep_dropoff_datetime: timestamp (nullable = true)
// -- trip_distance: double (nullable = true)
// -- fare_amount: double (nullable = true)
// -- pickup_zip: integer (nullable = true)
// -- dropoff_zip: integer (nullable = true)
//
// </div>

// %%
val lesson2 = input.withColumn("new_time", unix_timestamp($"tpep_dropoff_datetime") - unix_timestamp($"tpep_pickup_datetime"))
                   .agg(avg($"new_time")) //unix_timestamp là kết quả trả về giây.
display(lesson2)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg(new_time)</th></tr></thead><tbody><tr><td>906.9607878898413</td></tr></tbody></table></div>

// %% [markdown]
// Bài 3: Hãy tìm cặp zip code (`pickup_zip`, `dropoff_zip`) có quãng đường trung bình lớn nhất

// %%
val lesson3 = input.orderBy(desc("trip_distance")).select($"pickup_zip", $"dropoff_zip", $"trip_distance").limit(1)
display(lesson3)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zip</th><th>dropoff_zip</th><th>trip_distance</th></tr></thead><tbody><tr><td>11371</td><td>7114</td><td>30.6</td></tr></tbody></table></div>

// %% [markdown]
// Bài 4: Hãy hiển thị top 3 bản ghi có giá tiền lớn nhất theo mỗi cặp `pickup_zip`, `dropoff_zip`

// %%
// Kiểm tra các cặp pickup dropoff
val test = input.groupBy($"pickup_zip", $"dropoff_zip").count.orderBy(desc("count")).select($"pickup_zip", $"dropoff_zip").limit(3)
display(test)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zip</th><th>dropoff_zip</th></tr></thead><tbody><tr><td>10023</td><td>10023</td></tr><tr><td>10028</td><td>10028</td></tr><tr><td>10028</td><td>10021</td></tr></tbody></table></div>

// %%
import org.apache.spark.sql.expressions.Window
val w = Window.orderBy(desc("max_amount"))
val lesson4 = input.groupBy($"pickup_zip", $"dropoff_zip")
                   .agg(count("*").as("max_amount"))
                   .withColumn("top3", row_number().over(w))
                   .filter($"top3" <=3)
                   .drop("top3")
                   .join(input, Seq("pickup_zip", "dropoff_zip"))
                   .groupBy($"pickup_zip", $"dropoff_zip")
                   .agg(max($"fare_amount").as("max_fare_amount"))
display(lesson4)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zip</th><th>dropoff_zip</th><th>max_fare_amount</th></tr></thead><tbody><tr><td>10028</td><td>10028</td><td>52.0</td></tr><tr><td>10028</td><td>10021</td><td>13.0</td></tr><tr><td>10023</td><td>10023</td><td>52.0</td></tr></tbody></table></div>

// %%
// Cách 2 làm tuần tự
val top3 = input.groupBy($"pickup_zip", $"dropoff_zip")
                .agg(count("*").as("count"))

val w = Window.orderBy(desc("count"))
val top_pick_drop = top3.withColumn("top_3", row_number().over(w)).filter($"top_3" <= 3).drop("top_3") // cần xóa top_3 vì chỉ là giá trị trung gian để lọc lấy top 3 giá trị count lớn nhất

val result = input.join(top_pick_drop, Seq("pickup_zip", "dropoff_zip")) // dùng Seq để lọc và giữ lại những dòng ở input có cùng giá trị pickup và dropoff ở bảng top_pick_drop
                  .groupBy($"pickup_zip", $"dropoff_zip")
                  .agg(max($"fare_amount").as("max_fare_amount"))

display(result)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zip</th><th>dropoff_zip</th><th>max_fare_amount</th></tr></thead><tbody><tr><td>10028</td><td>10028</td><td>52.0</td></tr><tr><td>10028</td><td>10021</td><td>13.0</td></tr><tr><td>10023</td><td>10023</td><td>52.0</td></tr></tbody></table></div>

// %% [markdown]
// Bài 5: Hãy cho biết số tiền kiếm được của tất cả chuyến đi theo ngày trong tuần. Kết quả mẫu sẽ như sau:
//
// | Date_of_week | amount |
// | --- | --- |
// | Monday | 10.000 |
// | Tuesday | 20.000 |
// | ... | ...

// %%
val lesson5 = input.withColumn("Date_of_week", date_format($"tpep_dropoff_datetime", "EEEE"))
                   .groupBy($"Date_of_week")
                   .agg(round(sum($"fare_amount"), 4))
display(lesson5)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date_of_week</th><th>round(sum(fare_amount), 4)</th></tr></thead><tbody><tr><td>Wednesday</td><td>36602.6</td></tr><tr><td>Tuesday</td><td>34094.5</td></tr><tr><td>Friday</td><td>44542.01</td></tr><tr><td>Thursday</td><td>40820.02</td></tr><tr><td>Saturday</td><td>40136.5</td></tr><tr><td>Monday</td><td>37198.8</td></tr><tr><td>Sunday</td><td>37437.85</td></tr></tbody></table></div>

// %% [markdown]
// Sử dụng dữ liệu tại file: `dbfs:/FileStore/nyc_trips/FileNYC_Zipcode_Name.csv`. Thực hiện Join dữ liệu file với bảng `samples.nyctaxi.trips` theo trường `Zipcode` của CSV và trường `pickup_zip` của bảng

// %%
val zip_name = spark.read.option("header", "true").csv("dbfs:/FileStore/nyc_trips/FileNYC_Zipcode_Name.csv")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">zip_name: org.apache.spark.sql.DataFrame = [Borough: string, Neighborhood: string ... 1 more field]
// </div>

// %%
display(zip_name.limit(10))
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Borough</th><th>Neighborhood</th><th>ZipCode</th></tr></thead><tbody><tr><td>Bronx</td><td>Central Bronx</td><td>10453</td></tr><tr><td>Bronx</td><td>Central Bronx</td><td>10457</td></tr><tr><td>Bronx</td><td>Central Bronx</td><td>10460</td></tr><tr><td>Bronx</td><td>Bronx Park and Fordham</td><td>10458</td></tr><tr><td>Bronx</td><td>Bronx Park and Fordham</td><td>10467</td></tr><tr><td>Bronx</td><td>Bronx Park and Fordham</td><td>10468</td></tr><tr><td>Bronx</td><td>High Bridge and Morrisania</td><td>10451</td></tr><tr><td>Bronx</td><td>High Bridge and Morrisania</td><td>10452</td></tr><tr><td>Bronx</td><td>High Bridge and Morrisania</td><td>10456</td></tr><tr><td>Bronx</td><td>Hunts Point and Mott Haven</td><td>10454</td></tr></tbody></table></div>

// %% [markdown]
// Bài 6: Hãy cho biết Doanh thu của các quận trong thành phố với format như sau:
//
// | Tên trường | Ý nghĩa |
// | --- | --- |
// | borough | Tên quận (Brooklyn, Manhattan, ...) |
// | amount | Doanh thu |

// %%
val lesson6 = input.join(zip_name, $"pickup_zip" === $"ZipCode", "inner")
                   .groupBy($"Borough")
                   .agg(sum($"fare_amount").as("amount"))
display(lesson6)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Borough</th><th>amount</th></tr></thead><tbody><tr><td>Queens</td><td>23193.5</td></tr><tr><td>Brooklyn</td><td>5453.0</td></tr><tr><td>Manhattan</td><td>168325.62</td></tr><tr><td>Bronx</td><td>172.51</td></tr><tr><td>Staten Island</td><td>13.5</td></tr></tbody></table></div>
